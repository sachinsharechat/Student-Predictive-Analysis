# %%
import nbimporter
from question_feedback import add_to_head
import csv
import random

def count_magic(row,i,j,boolean):
    count=0
    if boolean:
        while i<=j:
            if row[i]=='C':
                count+=1
            i+=1
    else:
        while i<=j:
            if row[i]=='A':
                count+=1
            i+=1   
    return count
        
def assigning_label(row):
    row_complete=row
    row_complete.append('0')
    drop=count_magic(row,35,44,False)
    teacher=count_magic(row,54,62,True)
#     assigning
    if drop+teacher>=9:
        row_complete[-1]= random.randint(0,1)
    else:
        row_complete[-1]=0
    return row_complete
        
    
ifile=open('clean_data/clean_4.csv','r',newline='')
ofile=open('dropout_data_4.csv','w',newline='')
reader = csv.reader(ifile)
writer = csv.writer(ofile)
row_head=next(reader)
# making the header of csv
add_to_head(row_head)
row_head.append('dropout')
# writing the header
writer.writerow(row_head)
# main course
for row in reader:
    row_complete=assigning_label(row)
    writer.writerow(row_complete)
    

ifile.close()
ofile.close()

# %%
b=0
for i in row_complete:
    print(b,i)
    b+=1
# Out:
# 0 SHIVAM TYAGI
# 1 BRIJ BHUSHAN TYAGI
# 2 1402740150
# 3 1440178
# 4 ME
# 5 2014-18
# 6 ME-3
# 7 8
# 8 26-03-1997
# 9 GENERAL
# 10 NO
# 11 DIRECT
# 12 8791261803
# 13 9456292010
# 14 VILL & POST CHHAPAR MUZAFFARNAGAR UP 251001..
# 15 shivamtyagi532@gmail.com
# 16 88.00
# 17 88.4
# 18 77.36
# 19 82.3
# 20 90.95
# 21 79.7
# 22 88.44
# 23 73.1
# 24 80.67
# 25 72.9
# 26 80.43
# 27 79.1
# 28 85.02
# 29 79.6
# 30 82.15
# 31 74.8
# 32 79.18
# 33
# 34 43.82
# 35 A
# 36 D
# 37 D
# 38 C
# 39 D
# 40 A
# 41 B
# 42 A
# 43 C
# 44 B
# 45 A
# 46 A
# 47 C
# 48 B
# 49 A
# 50 C
# 51 B
# 52 B
# 53 C
# 54 C
# 55 A
# 56 A
# 57 B
# 58 B
# 59 B
# 60 B
# 61 B
# 62 A
# 63 0
