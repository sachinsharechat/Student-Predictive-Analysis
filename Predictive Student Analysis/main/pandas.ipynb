# %%
import pandas as pd

# %%
pd.read_csv('student_data_IT_2.csv')
# Out:
#                      Name                      Father     roll_no  student_no  \
# 0           Aabhas Saxena                Manoj Saxena  1602713001     1613118
# 1          Aabhas Agarwal            Prashant Agarwal  1602713002     1613031
# 2            Aarushi Garg                   Anuj Garg  1602713003     1613099
# 3           Aayushi Gupta          Rajesh Kumar Gupta  1602713004     1613100
# 4        Abhishek Chandel       Virendra Pratap Singh  1602713005     1613093
# 5          Abhishek Gupta          RadhaKrishna Gupta  1602713006     1613075
# 6    Abhishek Kumar Singh          Shri Prakash Singh  1602713007     1613098
# 7          Abhishek Singh                Rajeev Singh  1602713008     1613030
# 8          Abhishek Yadav               Nandlal Yadav  1602713009     1613027
# 9             Adarsh Garg              Ramavatar Garg  1602713010     1613057
# 10         Adarsh Jaiswal               Santosh Kumar  1602713011     1613065
# ...

# %%
table=pd.read_csv('student_data_IT_2.csv')

# %%
table.head()
# Out:
#                Name                 Father     roll_no  student_no branch  \
# 0     Aabhas Saxena           Manoj Saxena  1602713001     1613118     IT
# 1    Aabhas Agarwal       Prashant Agarwal  1602713002     1613031     IT
# 2      Aarushi Garg              Anuj Garg  1602713003     1613099     IT
# 3     Aayushi Gupta     Rajesh Kumar Gupta  1602713004     1613100     IT
# 4  Abhishek Chandel  Virendra Pratap Singh  1602713005     1613093     IT
#
#       year section  current_sem         DOB category        ...         \
# 0  2016-20    IT-1            4  11-05-1998  GENERAL        ...
# 1  2016-20    IT-1            4  08-04-1997  GENERAL        ...
# 2  2016-20    IT-1            4  18-01-1999  GENERAL        ...
# 3  2016-20    IT-1            4  19-03-1998  GENERAL        ...
# 4  2016-20    IT-1            4  24-03-1998  GENERAL        ...
#
#   sem_4_marks sem_4_attendance sem_5_marks sem_5_attendance sem_6_marks  \
# ...

# %%
ufo=pd.read_csv('student_data_IT_2.csv',sep=',')

# %%
type(ufo)
# Out:
# pandas.core.frame.DataFrame

# %%
ufo['Name']
# Out:
# 0             Aabhas Saxena
# 1            Aabhas Agarwal
# 2              Aarushi Garg
# 3             Aayushi Gupta
# 4          Abhishek Chandel
# 5            Abhishek Gupta
# 6      Abhishek Kumar Singh
# 7            Abhishek Singh
# 8            Abhishek Yadav
# 9               Adarsh Garg
# 10           Adarsh Jaiswal
# 11           Aditya Chauhan
# 12              Akash Gupta
# 13              Akash Verma
# 14              Aman Bharti
# 15          Ambuj Khyaliram
# 16              Anand Verma
# 17              Ankur Singh
# 18            Anmol Agarwal
# 19            Antra Jaiswal
# 20           Anukarsh Gupta
# 21       Anushka Srivastava
# 22           Arpit Kushwaha
# 23             Arpit Tiwari
# 24          Aryan Chaudhary
# 25             Ashish Kumar
# 26              Ashna Arora
# 27            Ayush Paliwal
# 28           Ayushi Awasthi
# 29           Bharat Agarwal
#                ...
# 88        Rohan Jai Prakash
# 89             Sagar Chawla
# ...

# %%
len(ufo)
# Out:
# 118

# %%
five=ufo.head()

# %%
len(five)
# Out:
# 5

# %%
print(five)
# Out:
#                Name                 Father     roll_no  student_no branch  \
# 0     Aabhas Saxena           Manoj Saxena  1602713001     1613118     IT
# 1    Aabhas Agarwal       Prashant Agarwal  1602713002     1613031     IT
# 2      Aarushi Garg              Anuj Garg  1602713003     1613099     IT
# 3     Aayushi Gupta     Rajesh Kumar Gupta  1602713004     1613100     IT
# 4  Abhishek Chandel  Virendra Pratap Singh  1602713005     1613093     IT
#
#       year section  current_sem         DOB category        ...         \
# 0  2016-20    IT-1            4  11-05-1998  GENERAL        ...
# 1  2016-20    IT-1            4  08-04-1997  GENERAL        ...
# 2  2016-20    IT-1            4  18-01-1999  GENERAL        ...
# 3  2016-20    IT-1            4  19-03-1998  GENERAL        ...
# 4  2016-20    IT-1            4  24-03-1998  GENERAL        ...
#
#   sem_4_marks sem_4_attendance sem_5_marks sem_5_attendance sem_6_marks  \
# ...

# %%
len(ufo)
# Out:
# 118

# %%
ufo['Name']
# Out:
# 0             Aabhas Saxena
# 1            Aabhas Agarwal
# 2              Aarushi Garg
# 3             Aayushi Gupta
# 4          Abhishek Chandel
# 5            Abhishek Gupta
# 6      Abhishek Kumar Singh
# 7            Abhishek Singh
# 8            Abhishek Yadav
# 9               Adarsh Garg
# 10           Adarsh Jaiswal
# 11           Aditya Chauhan
# 12              Akash Gupta
# 13              Akash Verma
# 14              Aman Bharti
# 15          Ambuj Khyaliram
# 16              Anand Verma
# 17              Ankur Singh
# 18            Anmol Agarwal
# 19            Antra Jaiswal
# 20           Anukarsh Gupta
# 21       Anushka Srivastava
# 22           Arpit Kushwaha
# 23             Arpit Tiwari
# 24          Aryan Chaudhary
# 25             Ashish Kumar
# 26              Ashna Arora
# 27            Ayush Paliwal
# 28           Ayushi Awasthi
# 29           Bharat Agarwal
#                ...
# 88        Rohan Jai Prakash
# 89             Sagar Chawla
# ...

# %%
ufo.year
# Out:
# 0      2016-20
# 1      2016-20
# 2      2016-20
# 3      2016-20
# 4      2016-20
# 5      2016-20
# 6      2016-20
# 7      2016-20
# 8      2016-20
# 9      2016-20
# 10     2016-20
# 11     2016-20
# 12     2016-20
# 13     2016-20
# 14     2016-20
# 15     2016-20
# 16     2016-20
# 17     2016-20
# 18     2016-20
# 19     2016-20
# 20     2016-20
# 21     2016-20
# 22     2016-20
# 23     2016-20
# 24     2016-20
# 25     2016-20
# 26     2016-20
# 27     2016-20
# 28     2016-20
# 29     2016-20
#         ...
# 88     2016-20
# 89     2016-20
# 90     2016-20
# 91     2016-20
# 92     2016-20
# 93     2016-20
# 94     2016-20
# 95     2016-20
# 96     2016-20
# 97     2016-20
# 98     2016-20
# 99     2016-20
# 100    2016-20
# 101    2016-20
# 102    2016-20
# 103    2016-20
# 104    2016-20
# 105    2016-20
# 106    2016-20
# 107    2016-20
# 108    2016-20
# 109    2016-20
# 110    2016-20
# 111    2016-20
# 112    2016-20
# 113    2016-20
# 114    2016-20
# 115    2016-20
# ...

# %%
ufo.category
# Out:
# 0      GENERAL
# 1      GENERAL
# 2      GENERAL
# 3      GENERAL
# 4      GENERAL
# 5      GENERAL
# 6      GENERAL
# 7          OBC
# 8      GENERAL
# 9      GENERAL
# 10         OBC
# 11     GENERAL
# 12     GENERAL
# 13     GENERAL
# 14     GENERAL
# 15     GENERAL
# 16     GENERAL
# 17     GENERAL
# 18     GENERAL
# 19         OBC
# 20     GENERAL
# 21     GENERAL
# 22         OBC
# 23     GENERAL
# 24         OBC
# 25          SC
# 26     GENERAL
# 27     GENERAL
# 28     GENERAL
# 29     GENERAL
#         ...
# 88     GENERAL
# 89     GENERAL
# 90     GENERAL
# 91     GENERAL
# 92     GENERAL
# 93     GENERAL
# 94     GENERAL
# 95         OBC
# 96     GENERAL
# 97     GENERAL
# 98         OBC
# 99     GENERAL
# 100    GENERAL
# 101    GENERAL
# 102    GENERAL
# 103    GENERAL
# 104        OBC
# 105    GENERAL
# 106    GENERAL
# 107    GENERAL
# 108    GENERAL
# 109        OBC
# 110    GENERAL
# 111    GENERAL
# 112    GENERAL
# 113        OBC
# 114    GENERAL
# 115    GENERAL
# ...

# %%
type(ufo['Name'])
# Out:
# pandas.core.series.Series

# %%
ufo.shape
# Out:
# (118, 35)

# %%
ufo.Name+' '+ufo.branch
# Out:
# 0             Aabhas Saxena IT
# 1            Aabhas Agarwal IT
# 2              Aarushi Garg IT
# 3             Aayushi Gupta IT
# 4          Abhishek Chandel IT
# 5            Abhishek Gupta IT
# 6      Abhishek Kumar Singh IT
# 7            Abhishek Singh IT
# 8            Abhishek Yadav IT
# 9               Adarsh Garg IT
# 10           Adarsh Jaiswal IT
# 11           Aditya Chauhan IT
# 12              Akash Gupta IT
# 13              Akash Verma IT
# 14              Aman Bharti IT
# 15          Ambuj Khyaliram IT
# 16              Anand Verma IT
# 17              Ankur Singh IT
# 18            Anmol Agarwal IT
# 19            Antra Jaiswal IT
# 20           Anukarsh Gupta IT
# 21       Anushka Srivastava IT
# 22           Arpit Kushwaha IT
# 23             Arpit Tiwari IT
# 24          Aryan Chaudhary IT
# 25             Ashish Kumar IT
# 26              Ashna Arora IT
# 27            Ayush Paliwal IT
# 28           Ayushi Awasthi IT
# 29           Bharat Agarwal IT
# ...

# %%
ufo['new_field']=ufo.Name+' '+ufo.branch

# %%
ufo.shape
# Out:
# (118, 36)

# %%
a=list(ufo)

# %%
a[34]
# Out:
# 'sem_8_attendance'

# %%
ufo.columns
# Out:
# Index(['Name', 'Father', 'roll_no', 'student_no', 'branch', 'year', 'section',
#        'current_sem', 'DOB', 'category', 'hostler', 'Addmission_mod',
#        'contact', 'parent_contact', 'address', 'email', 'high_school', 'intermediate',
#        'B_tech', 'sem_1_marks', 'sem_1_attendance', 'sem_2_marks',
#        'sem_2_attendance', 'sem_3_marks', 'sem_3_attendance', 'sem_4_marks',
#        'sem_4_attendance', 'sem_5_marks', 'sem_5_attendance', 'sem_6_marks',
#        'sem_6_attendance', 'sem_7_marks', 'sem_7_attendance', 'sem_8_marks',
#        'sem_8_attendance', 'new_field'],
#       dtype='object')

# %%
colums=pd.DataFrame()
colums['name']=ufo.Name

# %%
colums['roll_no']=ufo.roll_no

# %%
colums.shape
# Out:
# (118, 2)

# %%
colums.head()
# Out:
#                name     roll_no
# 0     Aabhas Saxena  1602713001
# 1    Aabhas Agarwal  1602713002
# 2      Aarushi Garg  1602713003
# 3     Aayushi Gupta  1602713004
# 4  Abhishek Chandel  1602713005

# %%
type(colums)
# Out:
# pandas.core.frame.DataFrame

# %%
type(ufo)
# Out:
# pandas.core.frame.DataFrame

# %%
a=colums.name

# %%
type(a)
# Out:
# pandas.core.series.Series

# %%
a.shape
# Out:
# (118,)

# %%
list(a)
# Out:
# ['Aabhas Saxena',
#  'Aabhas Agarwal',
#  'Aarushi Garg',
#  'Aayushi Gupta',
#  'Abhishek Chandel',
#  'Abhishek Gupta',
#  'Abhishek Kumar Singh',
#  'Abhishek Singh',
#  'Abhishek Yadav',
#  'Adarsh Garg',
#  'Adarsh Jaiswal',
#  'Aditya Chauhan',
#  'Akash Gupta',
#  'Akash Verma',
#  'Aman Bharti',
#  'Ambuj Khyaliram',
#  'Anand Verma',
#  'Ankur Singh',
#  'Anmol Agarwal',
#  'Antra Jaiswal',
#  'Anukarsh Gupta',
#  'Anushka Srivastava',
#  'Arpit Kushwaha',
#  'Arpit Tiwari',
#  'Aryan Chaudhary',
#  'Ashish Kumar',
#  'Ashna Arora',
#  'Ayush Paliwal',
#  'Ayushi Awasthi',
#  'Bharat Agarwal',
#  'Bharti Jaiswal',
#  'Devang Jain',
#  'Devansh Gupta',
#  'Dhananjay Vaish',
#  'Dipank Agarwal',
#  'Divyanshu Gupta',
#  'Gaurav Singh',
#  'Gaurav  Singh Kuntal',
#  'Hardik Agarwal',
#  'Harendra Singh',
#  'Harsh Gupta',
#  'Harsh Gupta',
#  'Harshdeep  Rana',
#  'Himanshu Gaba',
#  'Himanshu Pandey',
#  'Ishaan Bhattacharya',
#  'Ishit  Bansal',
#  'Ishita Tyagi',
# ...

# %%
type(colums.sort_values('name',ascending=False))
# Out:
# pandas.core.frame.DataFrame

# %%
colums.head()
# Out:
#                name     roll_no
# 0     Aabhas Saxena  1602713001
# 1    Aabhas Agarwal  1602713002
# 2      Aarushi Garg  1602713003
# 3     Aayushi Gupta  1602713004
# 4  Abhishek Chandel  1602713005

# %%
colums.drop(['Father'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-0c88334d1185> in <module>()
# ----> 1 colums.drop(['Father'],axis=1)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    2528         for axis, labels in axes.items():
#    2529             if labels is not None:
# -> 2530                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    2531
#    2532         if inplace:
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    2560                 new_axis = axis.drop(labels, level=level, errors=errors)
#    2561             else:
# -> 2562                 new_axis = axis.drop(labels, errors=errors)
#    2563             dropped = self.reindex(**{axis_name: new_axis})
#    2564             try:
#
# ...

# %%
ufo.drop(['new_field'],axis=1)

# %%
ufo.shape

# %%
boolean1=[]
for cat in ufo.category:
    if cat=='SC':
        boolean1.append(True)
    else:
        boolean1.append(False)
boolean2=[]
for cat in ufo.category:
    if cat=='OBC':
        boolean2.append(True)
    else:
        boolean2.append(False)
boolean3=[]
for cat in ufo.category:
    if cat=='GENERAL':
        boolean3.append(True)
    else:
        boolean3.append(False)

# %%
cat1=pd.Series(boolean1)
cat2=pd.Series(boolean2)
cat3=pd.Series(boolean3)

# %%
sum(ufo[cat1]['intermediate'])/len(ufo[cat1].sem_2_marks)

# %%
sum(ufo[cat2]['intermediate'])/len(ufo[cat2].sem_1_marks)

# %%
sum(ufo[cat3]['intermediate'])/len(ufo[cat3].sem_1_marks)

# %%
ufo[cat1].sem_3_marks

# %%
ufo.columns

# %%
cat1=ufo.category=='SC'

# %%
cat1.head()

# %%
new=pd.DataFrame()

new=ufo[cat1]

# %%
type(new)

# %%
for index, row in new.iterrows():
    print(index,row.Name, row['high_school'])

# %%
new.dtypes

# %%
new.drop(['new_field'],axis=1,inplace=True)

# %%
new.describe(include=[int,float])

# %%
new.shape

# %%
list(new.mean(axis=0))

# %%
new=pd.read_csv('student_data_cs_4.csv')

# %%
new.shape
# Out:
# (137, 35)

# %%
new.columns
# Out:
# Index(['Name', 'Father', 'roll_no', 'student_no', 'branch', 'year', 'section',
#        'current_sem', 'DOB', 'category', 'hostler', 'Addmission_mod',
#        'contact', 'parent_contact', 'address', 'email', 'high_school', 'intermediate',
#        'B_tech', 'sem_1_marks', 'sem_1_attendance', 'sem_2_marks',
#        'sem_2_attendance', 'sem_3_marks', 'sem_3_attendance', 'sem_4_marks',
#        'sem_4_attendance', 'sem_5_marks', 'sem_5_attendance', 'sem_6_marks',
#        'sem_6_attendance', 'sem_7_marks', 'sem_7_attendance', 'sem_8_marks',
#        'sem_8_attendance'],
#       dtype='object')

# %%
new['high_school'].mean()
# Out:
# 87.09138686131388

# %%
new['intermediate'].mean()
# Out:
# 85.17364963503648

# %%
new.groupby('Addmission_mod')['sem_3_marks'].mean()
# Out:
# Addmission_mod
# 2738          88.400000
# 32779         64.400000
# 37066         78.200000
# 39466         69.300000
# 40748         60.600000
# 5512          70.700000
# 57332         51.500000
# 5980          59.500000
# 6092          72.500000
# 6720          69.800000
# 6937          68.600000
# 7249          68.700000
# 8650          67.800000
# 8849          74.900000
# 9233          72.300000
# 9654939164    78.180000
# 9718931821    73.410000
# DIRECT        72.688333
# Direct        69.700000
# JEE 40702     80.800000
# JEE MAIN 3    69.400000
# JEE MAIN 5    77.100000
# JEE MAIN R    63.100000
# JEEMAIN 18    83.700000
# JEEMAIN 35    90.100000
# UPSEE  273    62.700000
# UPSEE - 93    71.000000
# UPSEE 2231    67.200000
# UPSEE 2261    73.600000
# UPSEE 2526    74.400000
#                 ...
# UPSEE 4946    57.500000
# UPSEE 4988    86.100000
# UPSEE 5046    69.900000
# UPSEE 5090    70.900000
# UPSEE 5140    65.800000
# UPSEE 5310    70.900000
# ...

# %%
type(boolean)
# Out:
# pandas.core.series.Series

# %%
boolean=new.Addmission_mod.str.isalpha()

# %%
boolen2=~boolean

# %%
new[boolean2].Addmission_mod='UPSEE'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-68-c84da637a6d1> in <module>()
# ----> 1 new[boolean2].Addmission_mod='UPSEE'
#
# NameError: name 'boolean2' is not defined

# %%
new.groupby("Addmission_mod")['Addmission_mod'].count()
# Out:
# Addmission_mod
# 2738           1
# 32779          1
# 37066          1
# 39466          1
# 40748          1
# 5512           1
# 57332          1
# 5980           1
# 6092           1
# 6720           1
# 6937           1
# 7249           1
# 8650           1
# 8849           1
# 9233           1
# 9654939164     1
# 9718931821     1
# DIRECT        60
# Direct         1
# JEE 40702      1
# JEE MAIN 3     1
# JEE MAIN 5     1
# JEE MAIN R     1
# JEEMAIN 18     1
# JEEMAIN 35     1
# UPSEE  273     1
# UPSEE - 93     1
# UPSEE 2231     1
# UPSEE 2261     1
# UPSEE 2526     1
#               ..
# UPSEE 4946     1
# UPSEE 4988     1
# UPSEE 5046     1
# UPSEE 5090     1
# UPSEE 5140     1
# UPSEE 5310     1
# UPSEE 5405     1
# UPSEE 5410     1
# UPSEE 5467     1
# UPSEE 5801     1
# UPSEE 6158     1
# UPSEE 6585     1
# UPSEE 6731     1
# UPSEE 7707     1
# UPSEE 8719     1
# UPSEE 8759     1
# UPSEE 9048     1
# UPSEE 9136     1
# UPSEE 9181     1
# UPSEE 9365     1
# ...

# %%
new.Addmission_mod.describe()
# Out:
# count        137
# unique        78
# top       DIRECT
# freq          60
# Name: Addmission_mod, dtype: object

# %%
def myfunction(string):
    if string =='DIRECT':
        return 1
    else:
        return 2
type(pd.DataFrame(new.Addmission_mod.apply(myfunction)))
# Out:
# pandas.core.frame.DataFrame

# %%
# %matplotlib inline
new['sem_1_marks'].plot(kind='hist')

# %%
new.isnull().sum()
# Out:
# Name                  0
# Father                0
# roll_no               0
# student_no            0
# branch                0
# year                  0
# section               0
# current_sem           0
# DOB                   0
# category              0
# hostler               0
# Addmission_mod        0
# contact               0
# parent_contact        0
# address               0
# email                 0
# high_school                 0
# intermediate                 0
# B_tech               0
# sem_1_marks           0
# sem_1_attendance      0
# sem_2_marks           0
# sem_2_attendance      0
# sem_3_marks           0
# sem_3_attendance      0
# sem_4_marks           0
# sem_4_attendance      0
# sem_5_marks           1
# sem_5_attendance      0
# sem_6_marks           0
# sem_6_attendance      1
# sem_7_marks           0
# sem_7_attendance      2
# sem_8_marks         136
# sem_8_attendance      2
# dtype: int64

# %%
new.loc[0:2,list(new.columns)[0:3]].shape
# Out:
# (3, 3)

# %%
new.columns
# Out:
# Index(['Name', 'Father', 'roll_no', 'student_no', 'branch', 'year', 'section',
#        'current_sem', 'DOB', 'category', 'hostler', 'Addmission_mod',
#        'contact', 'parent_contact', 'address', 'email', 'high_school', 'intermediate',
#        'B_tech', 'sem_1_marks', 'sem_1_attendance', 'sem_2_marks',
#        'sem_2_attendance', 'sem_3_marks', 'sem_3_attendance', 'sem_4_marks',
#        'sem_4_attendance', 'sem_5_marks', 'sem_5_attendance', 'sem_6_marks',
#        'sem_6_attendance', 'sem_7_marks', 'sem_7_attendance', 'sem_8_marks',
#        'sem_8_attendance'],
#       dtype='object')
